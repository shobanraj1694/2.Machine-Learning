# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Random_Forest.sav","rb"))
result=loaded_model.predict([[50000,60000,30000,40000,80000]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([86045.5657])
