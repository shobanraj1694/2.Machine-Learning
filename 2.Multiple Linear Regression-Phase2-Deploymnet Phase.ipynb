# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_MultipleLinearRegression.sav","rb"))

# %%
result=loaded_model.predict([[25000,30000,40000,20000,10000]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[12372896.94104862]])

# %%
result=loaded_model.predict([[0,0,0,0,0]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[42403.87087053]])
